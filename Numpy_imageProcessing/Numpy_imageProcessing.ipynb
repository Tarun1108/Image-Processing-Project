# %%
import numpy as np

# %%
it=[2,4,3,5]

# %%
n=np.array(it)

# %%
type(n)
# Out:
# numpy.ndarray

# %%
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt

# %%
pil = Image.open("./Thor.jpg")

# %%
arr = np.array(pil)

# %%
arr.shape
# Out:
# (246, 220, 3)

# %%
pil
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=220x246 at 0x64283D0>

# %%
cut = arr[:5,:5]

# %%
plt.imshow(arr)

# %%
work =arr.copy()

# %%
work[:,:,[1,2]]=0

# %%
plt.imshow(work)

# %%
grey=arr.mean(axis=2)

# %%
plt.imshow(grey)

# %%
plt.imshow(grey, cmap="gray")

# %%
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt

import cv2

# %%
frame = cv2.imread("Thor.jpg")

# %%
plt.imshow(frame)

# %%
rgb = cv2.cvtColor(frame,cv2.COLOR_BGR2RGB)

# %%
plt.imshow(rgb)

# %%
 classifier =  cv2.CascadeClassifier("./haarcascade_frontalface_default.xml")

# %%
faces = classifier.detectMultiScale(frame)

# %%
face =faces[0]

# %%
x,y,w,h=face

# %%
face = rgb[y:y+h,x:x+w]

# %%
plt.imshow(face)

# %%
put = cv2.rectangle(rgb,(x,y),(x+w,y+h),(0,0,255),4)

# %%
plt.imshow(put)
